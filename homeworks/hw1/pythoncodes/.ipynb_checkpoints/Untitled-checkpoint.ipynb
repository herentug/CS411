# %%
dic = {}

alp={'A':0, 'B':1, 'C':2, 'D':3, 'E':4, 'F':5, 'G':6, 'H':7, 'I':8, 'J':9, 'K':10, 'L':11, 'M':12, 'N':13, 'O':14, 'P':15, 'Q':16, 'R':17, 'S':18, 'T':19, 'U':20, 'V':21, 'W':22, 'X':23, 'Y':24, 'Z':25,      ' ':26, '.':27, ',': 28, '!': 29, '?':30}

# %%
val=0
for i in range(0,31):
    for j in range(0,31):
        bigram=""
        bigram+= alp.keys()[i]
        bigram+= alp.keys()[j]
        
        dic[bigram]=31*i + j
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-35bb643c7102> in <module>()
#       3         bigram=""
#       4         bigram+= alp.keys()[i]
# ----> 5         bigram+= alp.keys()[j]
#       6
#       7         dic[bigram]=31*i + j
#
# IndexError: list index out of range

# %%
print(dic)
# Out:
# {1: 'a', 'TS': 797, 'WC': 812, 'VL': 854, 'WB': 813, ' B': 38, ' C': 37, ' A': 36, ' F': 42, ' G': 41, ' D': 40, ' E': 39, ' J': 46, ' K': 45, ' H': 44, ' I': 43, ' N': 50, ' O': 49, ' L': 48, ' M': 47, ' R': 54, ' S': 53, ' P': 52, ' Q': 51, ' V': 58, ' W': 57, ' T': 56, ' U': 55, ' Z': 61, 'G.': 313, ' X': 60, ' Y': 59, 'WM': 822, 'GW': 336, 'GV': 337, '  ': 32, ' !': 31, 'GS': 332, 'GR': 333, 'GQ': 330, 'GP': 331, 'WK': 820, 'YM': 884, ' .': 34, 'GZ': 340, ' ,': 33, 'GX': 339, 'GG': 320, 'GF': 321, 'GE': 318, 'GD': 319, 'GC': 316, 'GB': 317, 'GA': 315, 'GO': 328, 'GN': 329, 'GM': 326, 'GL': 327, 'GK': 324, ' ?': 35, 'GI': 322, 'GH': 323, 'U ': 745, 'WW': 832, 'WV': 833, 'WU': 830, 'WT': 831, 'VO': 855, 'SR': 705, 'WS': 828, 'WR': 829, 'M!': 496, 'M ': 497, 'M,': 498, 'M.': 499, 'M?': 500, 'ST': 707, 'Z,': 932, 'SK': 696, 'Z.': 933, 'SJ': 697, 'Z ': 931, 'Z!': 930, 'WZ': 836, 'VQ': 857, 'Z?': 934, 'WY': 834, 'WX': 835, 'ZL': 947, 'ZM': 946, 'ZN': 949, 'ZO': 948, 'ZH': 943, 'ZI': 94
# ...
